# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os
load_dotenv()

# %%
loader = DirectoryLoader(
    path='books',
    glob='*.pdf',
    loader_cls=PyPDFLoader
)

# %%
docs = loader.load()

print(len(docs))
print(docs[0].metadata)
print(docs[0].page_content)    # To see first page of pdf content


# print(docs[5].metadata)      # 2nd pdf
# print(docs[5].page_content)


# print(docs[8].metadata)      # 3rd pdf
# print(docs[8].page_content)

# %%
# docs = loader.lazy_load()                            # Use lazy_load for heavy or large files

# for document in docs:
#     print(document.metadata)
